# %% [markdown]
# <a href="https://colab.research.google.com/github/rahil0710/AIML2-1/blob/main/AIML_A5_part1%2C2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#part 1
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('titanic')
print(df.head())
print(df.dtypes)
df.info()
print(df.columns)
sns.set(style="whitegrid")
numeric_features = ['age', 'fare', 'sibsp', 'parch']
df[numeric_features].hist(bins=20, figsize=(10, 8), color='skyblue', edgecolor='black')
plt.suptitle('Distribution of Numeric Features', fontsize=16)
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(x='survived', data=df, palette='Set2')
plt.title('Count of Survived vs Not Survived', fontsize=14)
plt.xticks([0, 1], ['Not Survived', 'Survived'])
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(x='sex', hue='survived', data=df, palette='Set1')
plt.title('Survival Count by Gender', fontsize=14)
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(x='pclass', hue='survived', data=df, palette='Set3')
plt.title('Survival Count by Passenger Class', fontsize=14)
plt.show()

plt.figure(figsize=(6, 4))
sns.barplot(x='pclass', y='survived', data=df, ci=None, palette='muted')
plt.title('Class-wise Survival Rate', fontsize=14)
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(x='sibsp', data=df, palette='coolwarm')
plt.title('Number of Siblings/Spouses Aboard', fontsize=14)
plt.show()

plt.figure(figsize=(6, 4))
sns.histplot(df['age'], kde=True, bins=30, color='green')
plt.title('Overall Age Distribution', fontsize=14)
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(x='pclass', y='age', data=df, palette='coolwarm')
plt.title('Class-wise Age Distribution', fontsize=14)
plt.show()

plt.figure(figsize=(6, 4))
sns.barplot(x='sibsp', y='survived', data=df, ci=None, palette='Set1')
plt.title('Survival Rate by Number of Siblings/Spouses Aboard', fontsize=14)
plt.show()


df['age'].fillna(df['age'].median(), inplace=True)
df.drop(columns=['deck', 'alive', 'who', 'adult_male'], inplace=True)
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['pclass'] = df['pclass'].astype(int)
df['embarked'] = df['embarked'].map({'S': 0, 'C': 1, 'Q': 2})
print(df.isnull().sum())
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# ...

# %%
# part 2
#que1
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
df = sns.load_dataset('titanic')
df['age'].fillna(df['age'].median(), inplace=True)
df.drop(columns=['deck', 'alive', 'who', 'adult_male'], inplace=True)
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['pclass'] = df['pclass'].astype(int)
df['embarked'] = df['embarked'].map({'S': 0, 'C': 1, 'Q': 2})
df.dropna(inplace=True)
X = df.drop(columns=['survived'])
Y = df['survived']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
#que2
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
df = sns.load_dataset('titanic')
print("Columns in dataset:", df.columns)
df['age'].fillna(df['age'].median(), inplace=True)
df.drop(columns=['deck', 'alive', 'who', 'adult_male'], errors='ignore', inplace=True)
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['pclass'] = df['pclass'].astype('category').cat.codes
if 'embarked' in df.columns:
    df['embarked'] = df['embarked'].map({'S': 0, 'C': 1, 'Q': 2})
df = pd.get_dummies(df, drop_first=True)
df.dropna(inplace=True)
X = df.drop(columns=['survived'])
Y = df['survived']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
model = LogisticRegression(max_iter=1000)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
conf_matrix = confusion_matrix(Y_test, Y_pred)
class_report = classification_report(Y_test, Y_pred)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
#que3
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
df = sns.load_dataset('titanic')
print("Columns in dataset:", df.columns)
df['age'].fillna(df['age'].median(), inplace=True)
df.drop(columns=['deck', 'alive', 'who', 'adult_male'], errors='ignore', inplace=True)
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['pclass'] = df['pclass'].astype('category').cat.codes
if 'embarked' in df.columns:
    df['embarked'] = df['embarked'].map({'S': 0, 'C': 1, 'Q': 2})
df = pd.get_dummies(df, drop_first=True)
df.dropna(inplace=True)
X = df.drop(columns=['survived'])
Y = df['survived']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
model = LogisticRegression(max_iter=1000)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
conf_matrix = confusion_matrix(Y_test, Y_pred)
class_report = classification_report(Y_test, Y_pred)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
#que4
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
penalties = np.logspace(-4, 4, 10)
f1_scores = []
for penalty in penalties:
    model = LogisticRegression(C=penalty, max_iter=1000)
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    f1 = f1_score(Y_test, Y_pred)
    f1_scores.append(f1)
plt.figure(figsize=(12, 6))
plt.scatter(penalties, f1_scores, color='blue', label='F1 Score vs Penalty')
plt.xscale('log')
plt.xlabel('Penalty (C)')
plt.ylabel('F1 Score')
plt.title('F1 Score as a Function of Penalty')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# X_train shape: (711, 10)
# X_test shape: (178, 10)
# Y_train shape: (711,)
# Y_test shape: (178,)
# Columns in dataset: Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# Accuracy: 0.8089887640449438
# Confusion Matrix:
#  [[90 19]
#  [15 54]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84       109
#            1       0.74      0.78      0.76        69
#
#     accuracy                           0.81       178
#    macro avg       0.80      0.80      0.80       178
# weighted avg       0.81      0.81      0.81       178
#
# Columns in dataset: Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# ...
